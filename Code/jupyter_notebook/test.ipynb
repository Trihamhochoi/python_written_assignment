# %%
import pandas as pd

# %%
ideal_dict = {'set1': {'ideal_set': 'y42', 'min_squared_error': 51.06278169329284, 'max_deviation': 0.4959680000000013}, 
        'set2': {'ideal_set': 'y41', 'min_squared_error': 48.99185159761221, 'max_deviation': 0.49770300000000134}, 
        'set3': {'ideal_set': 'y11', 'min_squared_error': 0.008431092973386822, 'max_deviation': 0.4989360000000005}, 
        'set4': {'ideal_set': 'y44', 'min_squared_error': 0.32555545670531044, 'max_deviation': 0.7525598929999999}}
ideal_key_ls = list(ideal_dict.keys())
ideal_value_ls = list(ideal_dict.values())
for a,b in zip(ideal_key_ls,ideal_value_ls):
    b['set'] = a
pd.DataFrame(ideal_value_ls)
# Out:
#   ideal_set  min_squared_error  max_deviation   set
# 0       y42          51.062782       0.495968  set1
# 1       y41          48.991852       0.497703  set2
# 2       y11           0.008431       0.498936  set3
# 3       y44           0.325555       0.752560  set4
